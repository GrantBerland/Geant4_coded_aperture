# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

import seaborn as sns;
sns.set_style("darkgrid")
sns.set(font_scale=1.5)

# %%
hits = pd.read_csv("../data/hits_at_75cm.csv", names=['x','y','z','x0','y0','z0','E'])
hits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8448 entries, 0 to 8447
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x       8448 non-null   float64
#  1   y       8448 non-null   float64
#  2   z       8448 non-null   float64
#  3   x0      8448 non-null   float64
#  4   y0      8448 non-null   float64
#  5   z0      8448 non-null   float64
#  6   E       8448 non-null   float64
# dtypes: float64(7)
# memory usage: 462.1 KB

# %%
plt.figure(figsize=(12,6));
plt.hist(hits.E, bins=100);
plt.xlabel('Energy [keV]');
plt.ylabel('Counts');
